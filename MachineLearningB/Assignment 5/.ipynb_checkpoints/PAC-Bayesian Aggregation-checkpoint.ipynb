# %%
import numpy as np
from sklearn import svm
import matplotlib.pyplot as plt
from scipy.stats import entropy
from sklearn.model_selection import train_test_split, GridSearchCV
from tqdm.notebook import tqdm
import time
import seaborn as sns
sns.set_style("ticks")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("ionosphere.data") as dat:
    dat = np.genfromtxt(dat,delimiter = ",",dtype=str)
    y = (dat[:,-1]=='g')*2-1 
    X = dat[:,:-1].astype(float)
    

X, X_test, y, y_test = train_test_split(X,y, test_size=0.2)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
def KL(p,q):
#     a = p*np.log(p/q)
#     b = (1-p)*np.log((1-p)/(1-q))
#     a[p == 0] = 0
#     b[p == 1] = 0
# #     b[q == 1] = np.inf
#     return a + b
    return entropy(p,q)

def bound(lambd,loss,rho,n,r,delta):
    
    a1 = np.sum(rho*loss.T)/(1-lambd/2)
    a2 = (KL(rho,1/m*np.ones(len(rho))) + np.log(2*np.sqrt(n-r)/delta))
    a3 = lambd*(1-lambd/2)*(n-r)
    
    res = a1 + a2/a3
    
    return res

# %%
# Baseline

t = time.time()
dts = []
baselosses = []
for _ in tqdm(range(100)):
    params = {'gamma': np.logspace(-3,3,7), "C": np.logspace(-4,4,9)}


    clf = svm.SVC()

    GS = GridSearchCV(clf,params)




    GS.fit(X_test, y_test)



    baseline = svm.SVC(C=GS.best_params_['C'],gamma=GS.best_params_['gamma'])

    baseline.fit(X,y)


    pred = baseline.predict(X_test)
    baseloss = np.sum(pred != y_test)/len(y_test)
    baselosses.append(baseloss)
    dts.append(time.time() - t)
    t = time.time()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# Update Rules
#
# rho = ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#             Doing the experiment

# %%
def DoRuns(ms):
    ids = [i for i in range(len(X))]

    r = 35
    n = 200

    Losses = []
    localtimes = []
    bounds = []
    for m in ms:
        starttime = time.time()
        samples = np.random.choice(ids,(m,r))

        Ls = []
        models = []
        for s in samples:
            clf = svm.SVC()
            clf.fit(X[s], y[s])
            models.append(clf)
            test = np.random.choice(list(set(ids).difference(s)),n-r)
            pred = clf.predict(X[test])
            Ls.append(np.sum(pred != y[test])/len(pred))

        Ls = np.array(Ls)

        lambds = np.ones(len(Ls))/len(Ls)
        rhos = np.ones(len(Ls))/len(Ls)
        delta = 0.05

        # Find rhos
        for i in range(40):

            # Lambda
            p1 = 2*(n-r)*np.sum(rhos*Ls.T)
            p2 = KL(rhos,1/m*np.ones(len(rhos)))
            p3 = np.log(2*np.sqrt(n-r)/delta)

            lambds = 2/(np.sqrt(p1/(p2+p3)+1)+1)

            # rho
            L_val_min = np.min(Ls)
            _sum = np.sum(1/m*np.exp(-lambds*(n-r)*(Ls-L_val_min)))
            rhos = (1/m*np.exp(-lambds*(n-r)*(Ls-L_val_min)))/(_sum)
        # Majority vote:

        scaled_guesses = np.array([model.predict(X_test) for model in models])
        guess = np.sign(np.sum(rhos*scaled_guesses.T,axis = 1))

        voted_accuracy = (np.sum(guess != y_test))/len(y_test)
        localtimes.append(time.time() - starttime)
        Losses.append(voted_accuracy)
        
        
        b = bound(lambds,voted_accuracy,rhos,n,r,delta)
        bounds.append(b)
        
    return (Losses, localtimes,bounds)


ms = np.unique(np.logspace(0.3,2.54,20).astype(int))


AllResults = []
times = []
bounds = []
for _ in tqdm(range(10)):
    r, t, b = DoRuns(ms)
    AllResults.append(r)
    times.append(t)
    bounds.append(b)

AllResults = np.array(AllResults)
times = np.array(times)
bounds = np.array(bounds)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
fig,ax1 = plt.subplots(figsize =(6,5))

plotloss = np.mean(AllResults,axis = 0)
yerr = np.std(AllResults,axis = 0)

ax1.errorbar(ms,plotloss,yerr=yerr,capsize =2,fmt='.',color = "black")
ax1.plot(ms,plotloss,color = "black",label = "Method from paper")
ax1.set_xscale("log")
ax1.set_ylabel("Loss",color = "black")





plotbase = np.mean(baselosses)
baseerr = np.std(baselosses)

ax1.errorbar(ms,plotbase*np.ones_like(ms),yerr=np.ones_like(ms)*baseerr,capsize =2,fmt='.',color = "red")
ax1.plot(ms,plotbase*np.ones_like(ms),color = "red",label="CV SVM")
ax1.set_xscale("log")
ax1.set_ylabel("Loss",color = "black")


plotbound = np.mean(bounds,axis = 0)
yerr = np.std(bounds,axis = 0)

ax1.errorbar(ms,plotbound,yerr=yerr,capsize =2,fmt='.',color = "grey")
ax1.plot(ms,plotbound,color = "Grey",label="Bound")
ax1.set_xscale("log")
ax1.set_ylabel("Loss",color = "black",fontsize =14)
ax2 = ax1.twinx()

plottimes = np.mean(times,axis = 0)
yerr = np.std(times,axis = 0)

ax2.fill_between(ms,plottimes+yerr,plottimes-yerr,alpha = 0.3)
ax2.plot(ms,plottimes,'--',label = "$t_m$")
ax2.set_ylim(0,0.8)
ax2.set_ylabel("Runtime (s)",fontsize =14)



basetime = np.mean(dts)
ax2.fill_between(ms,basetime+np.std(dts)/3,basetime-np.std(dts)/3,alpha = 0.3,color="red")
ax2.plot(ms,basetime*np.ones_like(ms),'--',label = "$t_{CV}$",c="red")
ax2.set_ylim(0,1)
ax2.set_ylabel("Runtime (s)")
ax1.set_xlabel("m",fontsize =14)

# sns.despine()
fig.legend(loc = (0.61,0.68))
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
