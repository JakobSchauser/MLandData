# %%
import Alexandria as library
import matplotlib.pyplot as plt
import numpy as np

# %%
width = 3
height = 4
xs = np.linspace(-5,15,101)

calc_perim = lambda x: np.sqrt((x)**2 + height**2) + np.sqrt((10-xs)**2+height**2) + width


library.plot.line(xs,calc_perim(xs))
